# %%
import numpy as np
import pandas as pd
import statsmodels.api as sm
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
from sklearn.cluster import KMeans

# %%
data = pd.read_csv("D:\python programs\dspl\\archive\ADANIPORTS.csv")
data
# Out:
#             Date      Symbol Series  Prev Close    Open     High     Low  \
# 0     2007-11-27  MUNDRAPORT     EQ      440.00  770.00  1050.00  770.00
# 1     2007-11-28  MUNDRAPORT     EQ      962.90  984.00   990.00  874.00
# 2     2007-11-29  MUNDRAPORT     EQ      893.90  909.00   914.75  841.00
# 3     2007-11-30  MUNDRAPORT     EQ      884.20  890.00   958.00  890.00
# 4     2007-12-03  MUNDRAPORT     EQ      921.55  939.75   995.00  922.00
# ...          ...         ...    ...         ...     ...      ...     ...
# 3317  2021-04-26  ADANIPORTS     EQ      725.35  733.00   739.65  728.90
# 3318  2021-04-27  ADANIPORTS     EQ      730.75  735.00   757.50  727.35
# 3319  2021-04-28  ADANIPORTS     EQ      749.15  755.00   760.00  741.10
# 3320  2021-04-29  ADANIPORTS     EQ      746.25  753.20   765.85  743.40
# 3321  2021-04-30  ADANIPORTS     EQ      746.75  739.00   759.45  724.50
#
#        Last   Close    VWAP    Volume      Turnover    Trades  \
# ...

# %%
# Using K-Means Clustering
x = data.iloc[:,5:7] # 1st for rows and second for columns
x
# Out:
#          High     Low
# 0     1050.00  770.00
# 1      990.00  874.00
# 2      914.75  841.00
# 3      958.00  890.00
# 4      995.00  922.00
# ...       ...     ...
# 3317   739.65  728.90
# 3318   757.50  727.35
# 3319   760.00  741.10
# 3320   765.85  743.40
# 3321   759.45  724.50
#
# [3322 rows x 2 columns]

# %%
kmeans = KMeans(3) # Creating three clusters
kmeans.fit(x)
# Out:
# KMeans(n_clusters=3)

# %%
identified_clusters = kmeans.fit_predict(x)
identified_clusters
# Out:
# array([1, 1, 1, ..., 1, 1, 1])

# %%
data_with_clusters = data.copy()
data_with_clusters['Clusters'] = identified_clusters 
plt.scatter(data_with_clusters['Open'],data_with_clusters['Close'],c=data_with_clusters['Clusters'],cmap='rainbow')
